# %% [markdown]
# <a href="https://colab.research.google.com/github/25wh1a0532-ui/NASSCOM/blob/main/Python_Fundamentals_Syntax%2C_Variables%2C_Data_Types%2C_and_I_O.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, Python!")

if True:
    print("This is indented correctly.")
else:
    print("This won't run.")

name = "Alice"
age = 25
height = 5.6


print("Name:", name)
print("Age:", age)
print("Height:", height)


name = 123
print("New value of name:", name)

#int
a = 10
print(type(a))



# Float
b = 3.14
print(type(b))



# String
c = "Python"
print(type(c))

# Boolean
d = True
print(type(d))

# List
e = [1, 2, 3, "four"]
print(type(e), e)

# Dictionary
f = {"name": "Alice", "age": 25}
print(type(f), f)


print("Welcome to Python I/O!")

user_name = input("Enter your name: ")
print("Hello,", user_name)


user_age = int(input("Enter your age: "))
print("You will be", user_age + 1, "next year.")
# Out:
# Hello, Python!
# This is indented correctly.
# Name: Alice
# Age: 25
# Height: 5.6
# New value of name: 123
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'list'> [1, 2, 3, 'four']
# <class 'dict'> {'name': 'Alice', 'age': 25}
# Welcome to Python I/O!
# Enter your name: nidhi
# Hello, nidhi
# Enter your age: 18
# You will be 19 next year.
