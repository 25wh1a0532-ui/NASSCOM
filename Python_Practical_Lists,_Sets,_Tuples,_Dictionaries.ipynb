# %% [markdown]
# <a href="https://colab.research.google.com/github/25wh1a0532-ui/NASSCOM/blob/main/Python_Practical_Lists%2C_Sets%2C_Tuples%2C_Dictionaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1. LISTS

fruits = ['apple', 'banana', 'cherry', 'apple']
print("Original list:", fruits)

print("First fruit:", fruits[0])

fruits.append('orange')
print("After appending:", fruits)

fruits.remove('banana')
print("After removing banana:", fruits)


print("Number of fruits:", len(fruits))
# Out:
# Original list: ['apple', 'banana', 'cherry', 'apple']
# First fruit: apple
# After appending: ['apple', 'banana', 'cherry', 'apple', 'orange']
# After removing banana: ['apple', 'cherry', 'apple', 'orange']
# Number of fruits: 4

# %%
dimensions = (10, 20, 30)
print("Tuple:", dimensions)

print("Second element:", dimensions[1])
# Out:
# Tuple: (10, 20, 30)
# Second element: 20

# %%
unique_numbers = {1, 2, 3, 2, 1}
print("Set (no duplicates):", unique_numbers)


unique_numbers.add(4)
print("After adding 4:", unique_numbers)

unique_numbers.remove(2)
print("After removing 2:", unique_numbers)


set_a = {1, 2, 3}
set_b = {3, 4, 5}
print("Union:", set_a | set_b)
print("Intersection:", set_a & set_b)
print("Difference (A - B):", set_a - set_b)
# Out:
# Set (no duplicates): {1, 2, 3}
# After adding 4: {1, 2, 3, 4}
# After removing 2: {1, 3, 4}
# Union: {1, 2, 3, 4, 5}
# Intersection: {3}
# Difference (A - B): {1, 2}

# %%
student = {
    'name': 'Alice',
    'age': 21,
    'course': 'Python'
}
print("Dictionary:", student)

print("Student name:", student['name'])

student['grade'] = 'A'
print("After adding grade:", student)

del student['age']
print("After deleting age:", student)

for key, value in student.items():
    print(f"{key}: {value}")# 🔹 1. DEFINING A BASIC FUNCTION

# A function is a block of code that performs a task and can be reused.

def greet():
    print("Hello! Welcome to Python Functions.")

# Calling the function
greet()


Hello! Welcome to Python Functions.

# 🔹 2. FUNCTION WITH PARAMETERS

def greet_user(name):
    print(f"Hello, {name}!")

greet_user("Alice")
greet_user("Bob")  # You can reuse the function with different arguments


Hello, Alice!
Hello, Bob!

# 🔹 3. FUNCTION WITH DEFAULT PARAMETERS

def greet_user(name="Guest"):
    print(f"Welcome, {name}!")

greet_user()         # Uses default
greet_user("Ravi")   # Overrides default


Welcome, Guest!
Welcome, Ravi!

# 🔹 5. USING *args (VARIABLE NUMBER OF POSITIONAL ARGUMENTS)

# *args lets you pass any number of positional arguments as a tuple

def print_names(*names):
    print("Names passed:", names)
    for name in names:
        print("Hello", name)

print_names("Alice", "bob", "Charlie")


Names passed: ('Alice', 'bob', 'Charlie')
Hello Alice
Hello bob
Hello Charlie

# 🔹 6. USING **kwargs (VARIABLE NUMBER OF KEYWORD ARGUMENTS)

# **kwargs lets you pass any number of keyword arguments as a dictionary

def print_info(**info):
    print("User Info:")
    for key, value in info.items():
        print(f"{key} = {value}")

print_info(name="Alice", age=25, city="Delhi")
# 🔹 1. DEFINING A BASIC FUNCTION

# A function is a block of code that performs a task and can be reused.

def greet():
    print("Hello! Welcome to Python Functions.")

# Calling the function
greet()


Hello! Welcome to Python Functions.

# 🔹 2. FUNCTION WITH PARAMETERS

def greet_user(name):
    print(f"Hello, {name}!")

greet_user("Alice")
greet_user("Bob")  # You can reuse the function with different arguments


Hello, Alice!
Hello, Bob!

# 🔹 3. FUNCTION WITH DEFAULT PARAMETERS

def greet_user(name="Guest"):
    print(f"Welcome, {name}!")

greet_user()         # Uses default
greet_user("Ravi")   # Overrides default


Welcome, Guest!
Welcome, Ravi!

# 🔹 5. USING *args (VARIABLE NUMBER OF POSITIONAL ARGUMENTS)

# *args lets you pass any number of positional arguments as a tuple

def print_names(*names):
    print("Names passed:", names)
    for name in names:
        print("Hello", name)

print_names("Alice", "bob", "Charlie")


Names passed: ('Alice', 'bob', 'Charlie')
Hello Alice
Hello bob
Hello Charlie

# 🔹 6. USING **kwargs (VARIABLE NUMBER OF KEYWORD ARGUMENTS)

# **kwargs lets you pass any number of keyword arguments as a dictionary

def print_info(**info):
    print("User Info:")
    for key, value in info.items():
        print(f"{key} = {value}")

print_info(name="Alice", age=25, city="Delhi")


User Info:
name = Alice
age = 25
city = Delhi

# 🔹 7. COMBINING *args AND **kwargs

def show_details(*args, **kwargs):
    print("Args:", args)
    print("Kwargs:", kwargs)

show_details(1, 2, 3, name="Ravi", city="Mumbai")


Args: (1, 2, 3)
Kwargs: {'name': 'Ravi', 'city': 'Mumbai'}

# 🔹 8. FUNCTION NESTING (CALL ONE FUNCTION INSIDE ANOTHER)

def multiply(a, b):
    return a * b

def square(n):
    return multiply(n, n)# 🔹 1. DEFINING A BASIC FUNCTION

# A function is a block of code that performs a task and can be reused.

def greet():
    print("Hello! Welcome to Python Functions.")

# Calling the function
greet()


Hello! Welcome to Python Functions.

# 🔹 2. FUNCTION WITH PARAMETERS

def greet_user(name):
    print(f"Hello, {name}!")

greet_user("Alice")
greet_user("Bob")  # You can reuse the function with different arguments


Hello, Alice!
Hello, Bob!

# 🔹 3. FUNCTION WITH DEFAULT PARAMETERS

def greet_user(name="Guest"):
    print(f"Welcome, {name}!")

greet_user()         # Uses default
greet_user("Ravi")   # Overrides default


Welcome, Guest!
Welcome, Ravi!

# 🔹 5. USING *args (VARIABLE NUMBER OF POSITIONAL ARGUMENTS)

# *args lets you pass any number of positional arguments as a tuple

def print_names(*names):
    print("Names passed:", names)
    for name in names:
        print("Hello", name)

print_names("Alice", "bob", "Charlie")


Names passed: ('Alice', 'bob', 'Charlie')
Hello Alice
Hello bob
Hello Charlie

# 🔹 6. USING **kwargs (VARIABLE NUMBER OF KEYWORD ARGUMENTS)

# **kwargs lets you pass any number of keyword arguments as a dictionary

def print_info(**info):
    print("User Info:")
    for key, value in info.items():
        print(f"{key} = {value}")

print_info(name="Alice", age=25, city="Delhi")


User Info:
name = Alice
age = 25
city = Delhi

# 🔹 7. COMBINING *args AND **kwargs

def show_details(*args, **kwargs):
    print("Args:", args)
    print("Kwargs:", kwargs)

show_details(1, 2, 3, name="Ravi", city="Mumbai")


Args: (1, 2, 3)
Kwargs: {'name': 'Ravi', 'city': 'Mumbai'}

# 🔹 8. FUNCTION NESTING (CALL ONE FUNCTION INSIDE ANOTHER)

def multiply(a, b):
    return a * b

def square(n):
    return multiply(n, n)

print("Square of 4:", square(4))


Square of 4: 16

print("Square of 4:", square(4))


Square of 4: 16

User Info:
name = Alice
age = 25
city = Delhi

# 🔹 7. COMBINING *args AND **kwargs

def show_details(*args, **kwargs):
    print("Args:", args)
    print("Kwargs:", kwargs)

show_details(1, 2, 3, name="Ravi", city="Mumbai")


Args: (1, 2, 3)
Kwargs: {'name': 'Ravi', 'city': 'Mumbai'}

# 🔹 8. FUNCTION NESTING (CALL ONE FUNCTION INSIDE ANOTHER)

def multiply(a, b):
    return a * b

def square(n):
    return multiply(n, n)

print("Square of 4:", square(4))


Square of 4: 16# 🔹 1. DEFINING A BASIC FUNCTION

# A function is a block of code that performs a task and can be reused.

def greet():
    print("Hello! Welcome to Python Functions.")

# Calling the function
greet()


Hello! Welcome to Python Functions.

# 🔹 2. FUNCTION WITH PARAMETERS

def greet_user(name):
    print(f"Hello, {name}!")

greet_user("Alice")
greet_user("Bob")  # You can reuse the function with different arguments


Hello, Alice!
Hello, Bob!

# 🔹 3. FUNCTION WITH DEFAULT PARAMETERS

def greet_user(name="Guest"):
    print(f"Welcome, {name}!")

greet_user()         # Uses default
greet_user("Ravi")   # Overrides default


Welcome, Guest!
Welcome, Ravi!

# 🔹 5. USING *args (VARIABLE NUMBER OF POSITIONAL ARGUMENTS)

# *args lets you pass any number of positional arguments as a tuple

def print_names(*names):
    print("Names passed:", names)
    for name in names:
        print("Hello", name)

print_names("Alice", "bob", "Charlie")


Names passed: ('Alice', 'bob', 'Charlie')
Hello Alice
Hello bob
Hello Charlie

# 🔹 6. USING **kwargs (VARIABLE NUMBER OF KEYWORD ARGUMENTS)

# **kwargs lets you pass any number of keyword arguments as a dictionary

def print_info(**info):
    print("User Info:")
    for key, value in info.items():
        print(f"{key} = {value}")

print_info(name="Alice", age=25, city="Delhi")


User Info:
name = Alice
age = 25
city = Delhi

# 🔹 7. COMBINING *args AND **kwargs

def show_details(*args, **kwargs):
    print("Args:", args)
    print("Kwargs:", kwargs)

show_details(1, 2, 3, name="Ravi", city="Mumbai")

     # 🔹 1. DEFINING A BASIC FUNCTION

# A function is a block of code that performs a task and can be reused.

def greet():
    print("Hello! Welcome to Python Functions.")

# Calling the function
greet()


Hello! Welcome to Python Functions.

# 🔹 2. FUNCTION WITH PARAMETERS

def greet_user(name):
    print(f"Hello, {name}!")

greet_user("Alice")
greet_user("Bob")  # You can reuse the function with different arguments


Hello, Alice!
Hello, Bob!

# 🔹 3. FUNCTION WITH DEFAULT PARAMETERS

def greet_user(name="Guest"):
    print(f"Welcome, {name}!")

greet_user()         # Uses default
greet_user("Ravi")   # Overrides default


Welcome, Guest!
Welcome, Ravi!

# 🔹 5. USING *args (VARIABLE NUMBER OF POSITIONAL ARGUMENTS)

# *args lets you pass any number of positional arguments as a tuple

def print_names(*names):
    print("Names passed:", names)
    for name in names:
        print("Hello", name)

print_names("Alice", "bob", "Charlie")


Names passed: ('Alice', 'bob', 'Charlie')
Hello Alice
Hello bob
Hello Charlie

# 🔹 6. USING **kwargs (VARIABLE NUMBER OF KEYWORD ARGUMENTS)

# **kwargs lets you pass any number of keyword arguments as a dictionary

def print_info(**info):
    print("User Info:")
    for key, value in info.items():
        print(f"{key} = {value}")

print_info(name="Alice", age=25, city="Delhi")


User Info:
name = Alice
age = 25
city = Delhi

# 🔹 7. COMBINING *args AND **kwargs

def show_details(*args, **kwargs):
    print("Args:", args)
    print("Kwargs:", kwargs)

show_details(1, 2, 3, name="Ravi", city="Mumbai")

     # 🔹 1. DEFINING A BASIC FUNCTION

# A function is a block of code that performs a task and can be reused.

def greet():
    print("Hello! Welcome to Python Functions.")

# Calling the function
greet()


Hello! Welcome to Python Functions.

# 🔹 2. FUNCTION WITH PARAMETERS

def greet_user(name):
    print(f"Hello, {name}!")

greet_user("Alice")
greet_user("Bob")  # You can reuse the function with different arguments


Hello, Alice!
Hello, Bob!

# 🔹 3. FUNCTION WITH DEFAULT PARAMETERS

def greet_user(name="Guest"):
    print(f"Welcome, {name}!")

greet_user()         # Uses default
greet_user("Ravi")   # Overrides default


Welcome, Guest!
Welcome, Ravi!

# 🔹 5. USING *args (VARIABLE NUMBER OF POSITIONAL ARGUMENTS)

# *args lets you pass any number of positional arguments as a tuple

def print_names(*names):
    print("Names passed:", names)
    for name in names:
        print("Hello", name)

print_names("Alice", "bob", "Charlie")


Names passed: ('Alice', 'bob', 'Charlie')
Hello Alice
Hello bob
Hello Charlie

# 🔹 6. USING **kwargs (VARIABLE NUMBER OF KEYWORD ARGUMENTS)

# **kwargs lets you pass any number of keyword arguments as a dictionary

def print_info(**info):
    print("User Info:")
    for key, value in info.items():
        print(f"{key} = {value}")

print_info(name="Alice", age=25, city="Delhi")


User Info:
name = Alice
age = 25
city = Delhi

# 🔹 7. COMBINING *args AND **kwargs

def show_details(*args, **kwargs):
    print("Args:", args)
    print("Kwargs:", kwargs)

show_details(1, 2, 3, name="Ravi", city="Mumbai")

     # 🔹 1. DEFINING A BASIC FUNCTION

# A function is a block of code that performs a task and can be reused.

def greet():
    print("Hello! Welcome to Python Functions.")

# Calling the function
greet()


Hello! Welcome to Python Functions.

# 🔹 2. FUNCTION WITH PARAMETERS

def greet_user(name):
    print(f"Hello, {name}!")

greet_user("Alice")
greet_user("Bob")  # You can reuse the function with different arguments


Hello, Alice!
Hello, Bob!

# 🔹 3. FUNCTION WITH DEFAULT PARAMETERS

def greet_user(name="Guest"):
    print(f"Welcome, {name}!")

greet_user()         # Uses default
greet_user("Ravi")   # Overrides default


Welcome, Guest!
Welcome, Ravi!

# 🔹 5. USING *args (VARIABLE NUMBER OF POSITIONAL ARGUMENTS)

# *args lets you pass any number of positional arguments as a tuple

def print_names(*names):
    print("Names passed:", names)
    for name in names:
        print("Hello", name)

print_names("Alice", "bob", "Charlie")


Names passed: ('Alice', 'bob', 'Charlie')
Hello Alice
Hello bob
Hello Charlie

# 🔹 6. USING **kwargs (VARIABLE NUMBER OF KEYWORD ARGUMENTS)

# **kwargs lets you pass any number of keyword arguments as a dictionary

def print_info(**info):
    print("User Info:")
    for key, value in info.items():
        print(f"{key} = {value}")

print_info(name="Alice", age=25, city="Delhi")


User Info:
name = Alice
age = 25
city = Delhi

# 🔹 7. COMBINING *args AND **kwargs

def show_details(*args, **kwargs):
    print("Args:", args)
    print("Kwargs:", kwargs)

show_details(1, 2, 3, name="Ravi", city="Mumbai")

     # 🔹 1. DEFINING A BASIC FUNCTION

# A function is a block of code that performs a task and can be reused.

def greet():
    print("Hello! Welcome to Python Functions.")

# Calling the function
greet()


Hello! Welcome to Python Functions.

# 🔹 2. FUNCTION WITH PARAMETERS

def greet_user(name):
    print(f"Hello, {name}!")

greet_user("Alice")
greet_user("Bob")  # You can reuse the function with different arguments


Hello, Alice!
Hello, Bob!

# 🔹 3. FUNCTION WITH DEFAULT PARAMETERS

def greet_user(name="Guest"):
    print(f"Welcome, {name}!")

greet_user()         # Uses default
greet_user("Ravi")   # Overrides default


Welcome, Guest!
Welcome, Ravi!

# 🔹 5. USING *args (VARIABLE NUMBER OF POSITIONAL ARGUMENTS)

# *args lets you pass any number of positional arguments as a tuple

def print_names(*names):
    print("Names passed:", names)
    for name in names:
        print("Hello", name)

print_names("Alice", "bob", "Charlie")


Names passed: ('Alice', 'bob', 'Charlie')
Hello Alice
Hello bob
Hello Charlie

# 🔹 6. USING **kwargs (VARIABLE NUMBER OF KEYWORD ARGUMENTS)

# **kwargs lets you pass any number of keyword arguments as a dictionary

def print_info(**info):
    print("User Info:")
    for key, value in info.items():
        print(f"{key} = {value}")

print_info(name="Alice", age=25, city="Delhi")


User Info:
name = Alice
age = 25
city = Delhi

# 🔹 7. COMBINING *args AND **kwargs

def show_details(*args, **kwargs):
    print("Args:", args)
    print("Kwargs:", kwargs)

show_details(1, 2, 3, name="Ravi", city="Mumbai")


Args: (1, 2, 3)
Kwargs: {'name': 'Ravi', 'city': 'Mumbai'}

# 🔹 8. FUNCTION NESTING (CALL ONE FUNCTION INSIDE ANOTHER)

def multiply(a, b):# 🔹 1. DEFINING A BASIC FUNCTION

# A function is a block of code that performs a task and can be reused.

def greet():
    print("Hello! Welcome to Python Functions.")

# Calling the function
greet()


Hello! Welcome to Python Functions.

# 🔹 2. FUNCTION WITH PARAMETERS

def greet_user(name):
    print(f"Hello, {name}!")

greet_user("Alice")
greet_user("Bob")  # You can reuse the function with different arguments


Hello, Alice!
Hello, Bob!

# 🔹 3. FUNCTION WITH DEFAULT PARAMETERS

def greet_user(name="Guest"):
    print(f"Welcome, {name}!")

greet_user()         # Uses default
greet_user("Ravi")   # Overrides default


Welcome, Guest!
Welcome, Ravi!

# 🔹 5. USING *args (VARIABLE NUMBER OF POSITIONAL ARGUMENTS)

# *args lets you pass any number of positional arguments as a tuple

def print_names(*names):
    print("Names passed:", names)
    for name in names:
        print("Hello", name)

print_names("Alice", "bob", "Charlie")


Names passed: ('Alice', 'bob', 'Charlie')
Hello Alice
Hello bob
Hello Charlie

# 🔹 6. USING **kwargs (VARIABLE NUMBER OF KEYWORD ARGUMENTS)

# **kwargs lets you pass any number of keyword arguments as a dictionary

def print_info(**info):
    print("User Info:")
    for key, value in info.items():
        print(f"{key} = {value}")

print_info(name="Alice", age=25, city="Delhi")


User Info:
name = Alice
age = 25
city = Delhi

# 🔹 7. COMBINING *args AND **kwargs

def show_details(*args, **kwargs):
    print("Args:", args)
    print("Kwargs:", kwargs)

show_details(1, 2, 3, name="Ravi", city="Mumbai")


Args: (1, 2, 3)
Kwargs: {'name': 'Ravi', 'city': 'Mumbai'}

# 🔹 8. FUNCTION NESTING (CALL ONE FUNCTION INSIDE ANOTHER)

def multiply(a, b):
    return a * b

def square(n):
    return multiply(n, n)

print("Square of 4:", square(4))


Square of 4: 16
    return a * b

def square(n):
    return multiply(n, n)

print("Square of 4:", square(4))


Square of 4: 16
Args: (1, 2, 3)
Kwargs: {'name': 'Ravi', 'city': 'Mumbai'}

# 🔹 8. FUNCTION NESTING (CALL ONE FUNCTION INSIDE ANOTHER)

def multiply(a, b):
    return a * b

def square(n):
    return multiply(n, n)

print("Square of 4:", square(4))


Square of 4: 16
Args: (1, 2, 3)
Kwargs: {'name': 'Ravi', 'city': 'Mumbai'}

# 🔹 8. FUNCTION NESTING (CALL ONE FUNCTION INSIDE ANOTHER)

def multiply(a, b):
    return a * b

def square(n):
    return multiply(n, n)

print("Square of 4:", square(4))


Square of 4: 16
Args: (1, 2, 3)
Kwargs: {'name': 'Ravi', 'city': 'Mumbai'}

# 🔹 8. FUNCTION NESTING (CALL ONE FUNCTION INSIDE ANOTHER)

def multiply(a, b):
    return a * b

def square(n):
    return multiply(n, n)

print("Square of 4:", square(4))


Square of 4: 16
Args: (1, 2, 3)
Kwargs: {'name': 'Ravi', 'city': 'Mumbai'}

# 🔹 8. FUNCTION NESTING (CALL ONE FUNCTION INSIDE ANOTHER)

def multiply(a, b):
    return a * b

def square(n):
    return multiply(n, n)

print("Square of 4:", square(4))


Square of 4: 16

keys = ['id', 'name', 'marks']
values = [101, 'John', 88]
student_info = dict(zip(keys, values))
print("Student Info from zip:", student_info)
# Out:
# Dictionary: {'name': 'Alice', 'age': 21, 'course': 'Python'}
# Student name: Alice
# After adding grade: {'name': 'Alice', 'age': 21, 'course': 'Python', 'grade': 'A'}
# After deleting age: {'name': 'Alice', 'course': 'Python', 'grade': 'A'}
# name: Alice
# course: Python
# grade: A
# Student Info from zip: {'id': 101, 'name': 'John', 'marks': 88}
